# %%
import numpy as np
import pandas as pd
income = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
income_without_tax = income * 0.7
expenses = np.random.randint(100, size=10) 
df = pd.DataFrame({'Income': income, 'Income without tax': income_without_tax, 'Expenses': expenses})
print(df)
first_quarter = df[df['Income'].isin([100, 200, 300])]
print(first_quarter)
plt.subplot(3, 1, 1)
plt.plot(income, marker='o', color='black', label='Income')
plt.title('Income by Month')
plt.xlabel('Month')
plt.ylabel('Income')
plt.xticks(ticks=np.arange(len(income)), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct'])
plt.legend()
savings = income_without_tax - expenses
plt.subplot(3, 1, 2)
plt.bar(np.arange(len(savings)), savings, color='orange')
plt.title('Savings by month')
plt.xlabel('Month')
plt.ylabel('Savings')
plt.xticks(ticks=np.arange(len(savings)), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct'])
plt.subplot(3, 1, 3)
plt.pie(savings, labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct'], autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('Savings distribution by month')
plt.tight_layout()
plt.show()
first_quarter = df[df['Income'].isin([100, 200, 300])]
second_quarter = df[df['Income'].isin([400, 500, 600])]
third_quarter = df[df['Income'].isin([700, 800, 900])]
fourth_quarter = df[df['Income'].isin([1000])]

average_incomes = {
    "Quarter 1": stats.mean(first_quarter['Income']),
    "Quarter 2": stats.mean(second_quarter['Income']),
    "Quarter 3": stats.mean(third_quarter['Income']),
    "Quarter 4": stats.mean(fourth_quarter['Income']),
}

print("Average Income per Quarter:")
for quarter, avg_income in average_incomes.items():
    print(f"{quarter}: {avg_income:.2f}")
# Out:
#    Income  Income without tax  Expenses
# 0     100                70.0        34
# 1     200               140.0        96
# 2     300               210.0        95
# 3     400               280.0        48
# 4     500               350.0        80
# 5     600               420.0         0
# 6     700               490.0        45
# 7     800               560.0        87
# 8     900               630.0        56
# 9    1000               700.0        99
#    Income  Income without tax  Expenses
# 0     100                70.0        34
# 1     200               140.0        96
# 2     300               210.0        95
# Average Income per Quarter:
# Quarter 1: 200.00
# Quarter 2: 500.00
# Quarter 3: 800.00
# Quarter 4: 1000.00

# %%
import matplotlib.pyplot as plt
import statistics as stats
